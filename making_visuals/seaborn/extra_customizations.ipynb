# %%
import env

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('pokemon.csv', index_col=0)

# %%
df.head()
# Out:
#                              Name Type 1  Type 2    HP  Attack  Defense  \
# Pokemon Id
# 1                       Bulbasaur  Grass  Poison  45.0    49.0     49.0
# 2                         Ivysaur  Grass  Poison  60.0    62.0     63.0
# 3                        Venusaur  Grass  Poison  80.0    82.0     83.0
# 3           VenusaurMega Venusaur  Grass  Poison  80.0   100.0    123.0
# 4                      Charmander   Fire     NaN  39.0    52.0     43.0
#
#             Sp. Atk  Sp. Def  Speed  Generation Legendary
# Pokemon Id
# 1              65.0     65.0   45.0         1.0     False
# 2              80.0     80.0   60.0         1.0     False
# 3             100.0    100.0   80.0         1.0     False
# 3             122.0    120.0   80.0         1.0     False
# 4              60.0     50.0   65.0         1.0     False

# %%
pkmn_type_colors = ['limegreen',  # Grass
                    'firebrick',  # Fire
                    'royalblue',  # Water
                    'greenyellow',  # Bug
                    'lightgrey',  # Normal
                    'darkorchid',  # Poison
                    'gold',  # Electric
                    'chocolate',  # Ground
                    'lightpink',  # Fairy
                    'tomato',  # Fighting
                    'magenta',  # Psychic
                    'sienna',  # Rock
                    'violet',  # Ghost
                    'lightcyan',  # Ice
                    'darkorange',]  # Dragon

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(16,10))
# Violin plot with Pokemon color palette
sns.violinplot(x='Type 1', y='Attack', data=df, 
               palette=pkmn_type_colors) # Set color palette
# Out:
# <AxesSubplot:xlabel='Type 1', ylabel='Attack'>

# %%
plt.figure(figsize=(16,10))
# Swarm plot with Pokemon color palette
sns.swarmplot(x='Type 1', y='Attack', data=df, 
              palette=pkmn_type_colors)
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 8.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Type 1', ylabel='Attack'>

# %% [markdown]
# # Stack the 2 plots on top of each other

# %%
# Set figure size with matplotlib
plt.figure(figsize=(16,10))
 
# Create plot
sns.violinplot(x='Type 1',
               y='Attack', 
               data=df, 
               inner=None, # Remove the bars inside the violins
               palette=pkmn_type_colors,
               alph=0.6)
 
sns.swarmplot(x='Type 1', 
              y='Attack', 
              data=df, 
              color='k', # Make points black
              alpha=0.8) # and slightly transparent
 
# Set title with matplotlib
plt.title('Attack by Type')
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 5.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 9.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'Attack by Type')
