# %% [markdown]
# # Tips on Working on Projects

# %% [markdown]
# ### Ryvyn's Presentation

# %% [markdown]
# https://www.canva.com/design/DAEaKR7F-aA/Z-YI-I5nNmAYoNwiqpqy_A/edit

# %% [markdown]
# ![Screen Shot 2021-03-30 at 1.02.45 PM.png](attachment:9bc7d714-c8b2-4a29-a301-dca3008f530c.png)

# %% [markdown]
# Where to ge the data?

# %% [markdown]
# ![Screen Shot 2021-03-30 at 1.03.21 PM.png](attachment:c172dc30-6790-419a-b1bc-3f0458e1917f.png)

# %% [markdown]
# Kaggle is amazing cause it tells you about the data that is out there
# - just search for what you want
# The you will get a synopsis and questions
# - you are preset with your business questions for you

# %% [markdown]
# Another wonderful way to start is to chek out a bunch of books.
# - libraries
# - e books
# books are great cause they show you how you read the code
# - your job to customize
#
# Apps are awesome too
# - programming hero
#
#
# ![Screen Shot 2021-03-30 at 1.05.30 PM.png](attachment:1bfab1ac-3a47-4bc5-b734-b8f0bc76aa4c.png)

# %% [markdown]
# You can also take one of the ones you have already done and make them better
#
# ![Screen Shot 2021-03-30 at 1.06.59 PM.png](attachment:bffa99ce-cc35-4f5f-acb4-e45945340d23.png)

# %% [markdown]
# Make sure to show off what you did! You are selling yourself!
#
# ![Screen Shot 2021-03-30 at 1.08.48 PM.png](attachment:83c957cc-c99f-4d38-9854-d9afab061c65.png)

# %% [markdown]
# Make sure to set it up on github
#
# ![Screen Shot 2021-03-30 at 1.08.27 PM.png](attachment:d69fdfe6-75de-47e2-972d-6f60b3b512bf.png)

# %% [markdown]
# The appendix in the curriculum has EVERYONES git hub
#
# ![Screen Shot 2021-03-30 at 1.09.48 PM.png](attachment:a53c1fdc-17af-4cfb-a4ca-91861a88ba43.png)
