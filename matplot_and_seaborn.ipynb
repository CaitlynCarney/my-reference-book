# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Where does one find colors to change their visualizations?
#
# Seaborn:
# - for color_palette, cubehelix_palette, and light_palette
#     - https://seaborn.pydata.org/tutorial/color_palettes.html
# - for solid colors (color='_____')
#     - ![image.png](attachment:cce70d15-fd0c-4bf1-a8d4-c67b7e2cb47e.png)
#         - this can also be used for matplotlib at times
#
# Matplotlib:
# - for named colors
#     - https://matplotlib.org/stable/gallery/color/named_colors.html
# - for color maps
#     - https://matplotlib.org/stable/tutorials/colors/colormaps.html

# %% [markdown]
# ## How does one change the color of one bar in a matplotlib bar graph?

# %%
barlist=plt.bar([1,2,3,4], [1,2,3,4])
barlist[0].set_color('r')
plt.show()

# %%
barlist=plt.bar([1,2,3,4], [1,2,3,4])
barlist[1].set_color('r')
plt.show()

# %% [markdown]
# How about making each one different??

# %%
barlist=plt.bar([1,2,3,4], [1,2,3,4])
barlist[0].set_color('skyblue')
barlist[1].set_color('lightcoral')
barlist[2].set_color('lawngreen')
barlist[3].set_color('violet')
plt.show()

# %% [markdown]
# ## How does one change the location of their legend in

# %% [markdown]
# `plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')`
#
# - `bbox_to_anchor`
#     - used to position the legend in conjunction with loc.
#         - (x, y, width, height) that the legend is placed in.
#
# - `loc`
#     - the location
#         - upper left
#         - best
#         - etc.
# ![Screen Shot 2021-03-19 at 9.17.21 AM.png](attachment:d9f5b1fc-4279-4260-a987-23c784bf1ea1.png)

# %% [markdown]
# ## How to change the Markers on Matplotlib?
#
# - markersize
#     - changes the size of the marker
# - marker
#     - changes the marker shape
# - markerfacecolor
#     - changes the color of the color of the marker
# - markeredgecolor
#     - changes the color of the markers boarders
# ![Screen Shot 2021-03-19 at 9.28.43 AM.png](attachment:b6d150e0-f742-444d-aeb6-4e8e3cd5092c.png)
# ![Screen Shot 2021-03-19 at 9.29.07 AM.png](attachment:8b3c85e0-9b20-4261-99fe-a71657c2c4b4.png)
# ![Screen Shot 2021-03-19 at 9.29.22 AM.png](attachment:2cd7e384-d498-4557-8f71-cee06213e35a.png)

# %%
plt.plot([1, 2, 3], marker='P', markersize=40, markerfacecolor='pink', markeredgecolor='black')

# %% [markdown]
# ## How to change line styles in Matplotlib
#
# - linewidth
#     - changes the width of the line
# - linestyle
#     - changes the style of the line
# - color
#     - changes color of the line
#
# ![Screen Shot 2021-03-19 at 9.27.44 AM.png](attachment:bab9635a-df94-4610-80ed-dc1c26ac23c9.png)

# %%
plt.plot([1, 2, 3], color='green', linestyle='dashed', marker='o',
     markerfacecolor='blue', markersize=12, linewidth=5.0)

# %% [markdown]
# ## What plots does Seaborn have? And how do you set them up?
#
# Fro more details on each plot type please go to:
# https://seaborn.pydata.org/examples/index.html
#
# Remember there are MANY ways to set up each type of plot it just takes time to learn how to set them up in different ways
#
# - lmplot
# - scatterplot
# - lineplot
# - displot
# - relplot
# - catplot
# - boxplot
# - violinplot
# - jointplot
# - stipplot
# - jointgrid
# - FacetGrid
# - boxenplot
# - heatmap
# - JointGrid
# - kdeplot
# - Pairgrid
# - residplot
# - swarmplot
# - clustermap
# - dogplot

# %% [markdown]
# ## What plots does Matplotlib have? And how do you set them up?
#
# Fro more details on each plot type please go to:
# https://matplotlib.org/stable/tutorials/introductory/sample_plots.html
#
# - Line plot [plot()]
#
# - Subplots [subplots()]
#
# - Images [imshow()]
#
# - Contour [ contour()]
#
# - Pseudocolor [ pcolormesh()]
#
# - Histograms [hist()]
#
# - Paths [path()]
#
# - Three-dimensional plotting
#
# - Streamplot [ streamplot()]
#
# - Ellipses
#
# - Bar charts
#
# - Pie charts
#
# - Tables
#
# - Scatter plots
#
# - GUI widgets
#
# - Filled curves
#
# - Date handling
#
# - Log plots
#
# - Polar plots
#
# - Legends
#
# - TeX-notation for text objects
#
# - Native TeX rendering
#
# - EEG GUI
#
# - XKCD-style sketch plots
